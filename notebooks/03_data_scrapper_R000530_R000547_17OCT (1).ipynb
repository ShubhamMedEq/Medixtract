# %%
! pip install pdfplumber
! pip install pypdf2
# !apt-get install tesseract-ocr
# !apt-get install ghostscript
# !pip install ocrmypdf
# Out:
# Requirement already satisfied: pdfplumber in /usr/local/lib/python3.10/dist-packages (0.11.4)
# Requirement already satisfied: pdfminer.six==20231228 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (20231228)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (10.4.0)
# Requirement already satisfied: pypdfium2>=4.18.0 in /usr/local/lib/python3.10/dist-packages (from pdfplumber) (4.30.0)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer.six==20231228->pdfplumber) (43.0.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20231228->pdfplumber) (2.22)
# Requirement already satisfied: pypdf2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ghostscript is already the newest version (9.55.0~dfsg1-0ubuntu5.9).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Requirement already satisfied: ocrmypdf in /usr/local/lib/python3.10/dist-packages (16.5.0)
# Requirement already satisfied: deprecation>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (2.1.0)
# Requirement already satisfied: img2pdf>=0.5 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (0.5.1)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (24.1)
# Requirement already satisfied: pdfminer-six>=20220319 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (20231228)
# Requirement already satisfied: pi-heif in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (0.18.0)
# Requirement already satisfied: pikepdf>=8.10.1 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (9.3.0)
# Requirement already satisfied: pillow>=10.0.1 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (10.4.0)
# Requirement already satisfied: pluggy>=1 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (1.5.0)
# Requirement already satisfied: rich>=13 in /usr/local/lib/python3.10/dist-packages (from ocrmypdf) (13.9.2)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer-six>=20220319->ocrmypdf) (3.4.0)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.10/dist-packages (from pdfminer-six>=20220319->ocrmypdf) (43.0.1)
# Requirement already satisfied: Deprecated in /usr/local/lib/python3.10/dist-packages (from pikepdf>=8.10.1->ocrmypdf) (1.2.14)
# Requirement already satisfied: lxml>=4.8 in /usr/local/lib/python3.10/dist-packages (from pikepdf>=8.10.1->ocrmypdf) (4.9.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13->ocrmypdf) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13->ocrmypdf) (2.18.0)
# Requirement already satisfied: typing-extensions<5.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from rich>=13->ocrmypdf) (4.12.2)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (1.17.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=13->ocrmypdf) (0.1.2)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from Deprecated->pikepdf>=8.10.1->ocrmypdf) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer-six>=20220319->ocrmypdf) (2.22)

# %% [markdown]
# ## Import data

# %%
import PyPDF2 as pdf
import pandas as pd
import json
import pdfplumber
import ocrmypdf
import re
from datetime import datetime

# %% [markdown]
# ## CPT code and Description

# %%
file_path = r"Mario_Gutierrez_BR.xlsx"
sheet_name = 'CPT DESC'  # Your sheet name

# Read the Excel file into a DataFrame
df_cpt = pd.read_excel(file_path, sheet_name=sheet_name, dtype={'Procedure Code': str, 'Description': str})

# %% [markdown]
# ##

# %%
input_pdf = r'R000530 - R000547 M. Gutierrez_Allied Health_Billing.pdf'
data = []

# Open the PDF using pdfplumber
with pdfplumber.open(input_pdf) as pdf:
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            data.append({
                'page': page.page_number,
                'text': text
            })

# %%
print(data)
# Out:
# [{'page': 1, 'text': 'PERTAIN TO : Mario Alberto Gutierrez\nFROM : Allied Health\n814 West Mcneese Street, Suite 100.\nLAKE CHARLES., LOUISIANA 70605\nPHONE : (337) 602-8686 FAX : No fax number on file\nRECORD TYPE : Billing\nDELIVER TO : Trent Shelton\nARNOLD & ITKIN, LLP\n6009 MEMORIAL DRIVE\nHOUSTON, TEXAS 77007\nPHONE : (713) 222-3800 FAX : (713) 222-3850\nOrder No : 225590-1-35\nMARIO GUTIERREZ\nR000530'}, {'page': 2, 'text': 'CAUSE NO.\nAFFIDAVIT\nRecords Pert ning fo. Marlo Alberto Gutierrez\nType of Re rdsiAny and all ailing records FROM 06:2 1202: PRESENT pectamning to\nii S Gutters DOB 2797 SEN 494 including but et finited to, any\naa Hemized line nts, ledger cards andlor sheats, insuranc:tocl Tai hm es, an any aaft\nuocuments canta ined Sor ite egarding charge: incurred taining examinatios\ntre: ment batent\nBetore me the w sunhonty. pers onaily 0 Laphe\nng by me duly svar capasen as\n;\nPa - a the Is\nase on fa " Fi Hi i wl : pa nic ih re\nVan - a cian of 2a for Alh z\nthis att itare rac tne sere\n2 ed 2 i 1 prov ; itemize 4sia to\nares thay thie patee om\npart thi\nat ed ee are of\nane\naff\nat: ned rac\nhe rds a hisfacil hy he equis ealuse aus and t\nmp rratiy 20 i\nnsnit informa\nrowed he s re wed make er i lo fed\nThe mi fe in the egul irs of t siness, ear he\nafter\nnably i et a ded records the\nup ofthe original\nor ro halthe es ves ne urt char ine\nea ssonabie at the t ard Se provide\not unt wad\nThe fo ae cee a th\na Hi\n7 he has all ny adja iments\ncane\nAi INT\nS JORN TO AND SUBSCRI nefore ot\na PA wa\nPuble\nse.on\n-amm Eanes\nLu\nOrder No, 225590-1-38\nMARIO GUTIERREZ\nR000531'}, {'page': 3, 'text': '9:59 AM Gassan M. Chaiban, MD\n07/03/24\nFind Report\nAccrual Basis\nType Date Num Name All TransactioMnesmo Paid Open Balance Balance\nInvoice 05/15/2024 432 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban Inv 05/15/2024 Unpaid 500.00 500.00\nInvoice 04/12/2024 188 Arnold & Itkin:Mario Gutierrez Guiterrez, Mario; Chaiban Inv 04/12/2024 Unpaid 500.00 1,000.00\nInvoice 03/28/2024 116 Arnold & Itkin:Mario Gutierrez Guiterrez, Mario; Chaiban IV 03/28/2024 Unpaid 9,500.00 10,500.00\nInvoice 03/20/2024 103 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 03/20/2024 Unpaid 500.00 11,000.00\nInvoice 02/16/2024 39 Arnold & Itkin:Mario Gutierrez Guiterrez, Mario; Chaiban IV 02/16/2024 Unpaid 500.00 11,500.00\nInvoice 02/01/2024 11 Arnold & Itkin:Mario Gutierrez Guiterrez, Mario; Chaiban IV 02/01/2024 Unpaid 7,500.00 19,000.00\nInvoice 01/05/2024 7 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 01/05/2024 Unpaid 500.00 19,500.00\nInvoice 12/08/2023 308 Arnold & Itkin:Mario Gutierrez Guiterrez, Mario; Chaiban IV 12/08/2023 Unpaid 5,500.00 25,000.00\nInvoice 11/29/2023 307 Arnold & Itkin:Mario Gutierrez Gutierrez Mario; Chaiban IV 11/29/2023 Unpaid 250.00 25,250.00\nInvoice 11/10/2023 306 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 11/10/2023 Unpaid 5,000.00 30,250.00\nInvoice 10/27/2023 305 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 10/27/2023 Unpaid 500.00 30,750.00\nInvoice 10/13/2023 304 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 10/13/2023 Unpaid 5,000.00 35,750.00\nInvoice 09/29/2023 303 Arnold & Itkin:Mario Gutierrez Gutierrez Mario; Chaiban IV 09/29/2023 Unpaid 500.00 36,250.00\nInvoice 08/15/2023 302 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban 08/15/2023 Unpaid 250.00 36,500.00\nInvoice 07/21/2023 301 Arnold & Itkin:Mario Gutierrez Gutierrez, Mario; Chaiban IV 07/21/2023 Unpaid 1,000.00 37,500.00\nTotal 37,500.00 37,500.00\nPage 1 of 1\nR000532\nMARIO\nGUTIERREZ\n0001'}, {'page': 4, 'text': 'f ALLIED\n82-2152448\nDate Invoice #\n814 W. McNeese Street 8/15/2023 28974\nSuite 100\nLake Charles, LA 70605\n337-602-8686\nBill To\nAccess Healthcare Management\nP.O. Box 4910\nLake Charles, LA 70606\nP.O. No. Terms Project\nMario A. Gutierrez\nQuantity Description Rate Amount\n1 Dr. Chaiban - Appt. No Show Fee - DOS:08/15/20 ...

# %% [markdown]
# ## Function to Capture **HOSPITAL NAME** from page 1 PDF

# %%
def extract_hospital_name(text):
    # Adjusted regex pattern to capture the hospital name after "FROM :"
    match = re.search(r"FROM\s*:\s*([^\n]+)", text)
    if match:
        return match.group(1).strip()  # Return the captured group
    return "Unknown Hospital"

# %%
first_page = data[0] # First_page dic format
extract_hospital_name(first_page['text']) # extracting hospital name from first page
# Out:
# 'Allied Health'

# %% [markdown]
# ## Function for **HEALTH CLAIM FORM** from page 5 of PDF

# %%
def allied_health_claim_form(data, start_page=4):
    # Define regex patterns
    date_pattern = r'(\d{2} \d{2} \d{2})'  # Dates in MM DD YY format
    service_line_pattern = r'(\d{2} \d{2} \d{2}).+?(\b[A-Z]?\d{4,5}\b).+?(\d+)'  # Date, CPT, Charge

    # Extract hospital name from the first page
    hospital_name = extract_hospital_name(data[0]['text'])

    records = []

    # Iterate through pages starting from the specified page index
    for page_data in data[start_page:]:
        text = page_data['text']

        # Extract dates and convert them to datetime objects
        dates = re.findall(date_pattern, text)
        from_date = datetime.strptime(dates[0], '%m %d %y') if dates else None
        to_date = datetime.strptime(dates[-1], '%m %d %y') if len(dates) > 1 else None

        # Extract service lines: Date, CPT/HCPCS codes, and charges
        service_lines = re.findall(service_line_pattern, text)

        # Append extracted records to the list
        for service_date, code, charge in service_lines:
            service_date_obj = datetime.strptime(service_date, '%m %d %y')

            record = {
                "Page": page_data['page'],
                "Hospital": hospital_name,
                "TO Date": to_date,
                "CPT": str(code),
                "Charges": float(charge)  # Convert charge to float
            }
            records.append(record)

    # Create a DataFrame from the list of records
    df_claim_info = pd.DataFrame(records)

    return df_claim_info

# %%
df_extracted = allied_health_claim_form(data)

# %%
final_data = pd.merge(df_extracted,df_cpt,left_on='CPT', right_on='Procedure Code', how='left')
final_data.drop(columns=['Procedure Code'], inplace=True)
final_data.rename(columns={'Description': 'Provided_Description'}, inplace=True)
# Out:
#    Page       Hospital    TO Date    CPT  Charges Provided_Description
# 0     5  Allied Health 2023-09-29  99213    500.0         Office Visit
# 1     6  Allied Health 2024-02-01  62323   5000.0     Njx interlaminar
# 2     7  Allied Health 2024-01-05  99213    500.0         Office Visit
# 3     8  Allied Health 2024-02-16  99213    500.0         Office Visit
# 4     9  Allied Health 2024-03-20  99442    500.0           Phone e/m

# %%
final_data
# Out:
#     Page       Hospital    TO Date    CPT  Charges Provided_Description
# 0      5  Allied Health 2023-09-29  99213    500.0         Office Visit
# 1      6  Allied Health 2024-02-01  62323   5000.0     Njx interlaminar
# 2      7  Allied Health 2024-01-05  99213    500.0         Office Visit
# 3      8  Allied Health 2024-02-16  99213    500.0         Office Visit
# 4      9  Allied Health 2024-03-20  99442    500.0           Phone e/m
# 5     10  Allied Health 2024-04-12  99213    500.0         Office Visit
# 6     11  Allied Health 2024-03-28  62321   8000.0     Njx interlaminar
# 7     11  Allied Health 2024-03-28  Q9967      0.0     LOCM 300-399mg/m
# 8     11  Allied Health 2024-03-28  S0020      0.0     InjeCTion, bupiv
# 9     11  Allied Health 2024-03-28  J1100      0.0     Dexamethasone so
# 10    11  Allied Health 2024-03-28  E1399   1500.0                  NaN
# 11    12  Allied Health 2024-05-15  99213    500.0         Office Visit
# 12    13  Allied Health 2023-07-21  99204   1000.0         Office Visit
# 13    14  Allied Health 2023-12-08  62321   5500.0     Njx interlaminar
# 14    15  Allied Health 2023-10-13  62323   5000.0     Njx interlaminar
# 15    16  Allied Health 2023-10-27  99213    500.0         Office Visit
# 16    17  Allied Health 2023-11-10  62323   5000.0     Njx interlaminar
# 17    18  Allied Health 2023-11-29  99442    250.0           Phone e/m

# %% [markdown]
# ## Function for **Access Healthcare Management Invoice** page 4 PDF

# %%
page_5 = data[3]['text']

# %%
data[3]['text']
# Out:
# 'f ALLIED\n82-2152448\nDate Invoice #\n814 W. McNeese Street 8/15/2023 28974\nSuite 100\nLake Charles, LA 70605\n337-602-8686\nBill To\nAccess Healthcare Management\nP.O. Box 4910\nLake Charles, LA 70606\nP.O. No. Terms Project\nMario A. Gutierrez\nQuantity Description Rate Amount\n1 Dr. Chaiban - Appt. No Show Fee - DOS:08/15/2023 250.00 250.00\nPayments/Credits\n$0.00\nBalance Due $250.00\n0002\nMARIO GUTIERREZ\nR000533'

# %%
def extract_invoice_details(text):
    # Define refined regex patterns
    date_pattern = r'\b(\d{1,2}/\d{1,2}/\d{4})\b'  # Matches dates in MM/DD/YYYY format
    description_pattern = r'([A-Za-z\s\.\-]+Appt\. No Show Fee)'  # Matches specific description pattern
    amount_pattern = r'\b(\d{1,3}(?:,\d{3})*(?:\.\d{2})?)\b'  # Matches monetary values

    # Extract values using regex
    dates = re.findall(date_pattern, text)
    descriptions = re.findall(description_pattern, text)
    amounts = re.findall(amount_pattern, text)

    # Extract last amount as Balance Due (assuming the last occurrence is the total amount)
    balance_due = float(amounts[-1].replace(',', '')) if amounts else 0.0

    # Create records from extracted data
    records = []
    for i, description in enumerate(descriptions):
        record = {
            "Date": dates[i] if i < len(dates) else None,
            "Description": description.strip(),
            "Amount": balance_due if i == len(descriptions) - 1 else float(amounts[i].replace(',', ''))
        }
        records.append(record)

    # Create a DataFrame from the extracted data
    df_invoice = pd.DataFrame(records)

    return df_invoice

# %%
extract_invoice_details(page_5)
# Out:
#         Date                      Description  Amount
# 0  8/15/2023  Dr. Chaiban - Appt. No Show Fee   250.0

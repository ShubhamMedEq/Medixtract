# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in c:\users\vijaysisodiya\anaconda3\lib\site-packages (1.24.11)

# %%
import fitz
import re
from datetime import datetime
import pandas as pd

# %% [markdown]
# ### Creating CPT  Dictionary

# %%
# Load the Excel file (replace with the actual file path)
file_path = r"Mario_Gutierrez_BR.xlsx"
sheet_name = 'CPT DESC'  # Your sheet name

# Read the Excel file into a DataFrame
df_cpt = pd.read_excel(file_path, sheet_name=sheet_name, dtype={'Procedure Code': str, 'Description': str})

# %%
df_cpt.head()
# Out:
#   Procedure Code       Description
# 0          95004  Percut allergy s
# 1          95010  PERCUT ALLERGY T
# 2          95012  Exhaled nitric o
# 3          95015  ID ALLERGY TITRA
# 4          95017  Perq & icut allg

# %% [markdown]
# ### Hospital Name extraction

# %%
my_path = r'R000345 - R000349 M. Gutierrez_The Houston Spine & Rehabilitation Centers_Billing.pdf'
doc = fitz.open(my_path)

# %%
page = doc[0]
all_infos = page.get_text(sort=True)
print(all_infos)
# Out:
#       PERTAIN TO :    Mario Alberto Gutierrez
#
#          FROM :    The Houston Spine & Rehabilitation Centers
#                       3101 College Park Dr.
#                    THE WOODLANDS., TEXAS 77384
#
#
#
#         PHONE :    (281) 362-0006          FAX :  No fax number on file
#
#    RECORD TYPE :     Billing
#
#
#       DELIVER TO :    Trent Shelton
#
#                  ARNOLD & ITKIN, LLP
#                       6009 MEMORIAL DRIVE
#                   HOUSTON, TEXAS 77007
#
#
#         PHONE :    (713) 222-3800          FAX :   (713) 222-3850
#
#
#
#
#
# Order No : 225590-1-32
#
#                                                    MARIO GUTIERREZ
#                                                                   R000345

# %%
def extract_hospital_name(text):

    match = re.search(r"FROM\s*:\s*([^\n]+)", text)
    if match:
        return match.group(1).strip() 
    return "Unknown Hospital"

# %%
extract_hospital_name(all_infos)
# Out:
# 'The Houston Spine & Rehabilitation Centers'

# %% [markdown]
# ### Hospital Billing Extraction

# %%
import fitz  # PyMuPDF
import re
import pandas as pd
from datetime import datetime

def extract_hospital_name(text):
    match = re.search(r"FROM\s*:\s*([^\n]+)", text)
    if match:
        return match.group(1).strip()
    return "Unknown Hospital"

def extract_billing_info_pdf(file_path):
    # Open the PDF file
    doc = fitz.open(file_path)
    billing_records = []

    # Extract hospital name from the first page of the PDF
    
    first_page_text = doc[0].get_text(sort=True)
    hospital_name = extract_hospital_name(first_page_text)

    # Loop through each page of the PDF
    for page in doc:
        # Extract the text from the page
        all_medicine = page.get_text(sort=True)

        # Regular expression pattern to match the relevant billing data
        pattern = r'(\d{2}/\d{2}/\d{4})\s+Charge\s+[A-Za-z,\s]+\s+([A-Z0-9]*[0-9]+[A-Z0-9]*)\s+([\w\s\+\-\.\,\(\)]+)\s+(\d+\.\d{2})\s+(\d+\.\d{2})'

        # Find all matches in the text
        matches = re.findall(pattern, all_medicine)

        # Loop through each match and create a record
        for match in matches:
            record = {
                "Hospital": hospital_name,  # Add hospital name here
                "Date": datetime.strptime(match[0], '%m/%d/%Y'),  # Convert to datetime object
                "CPT": str(match[1]),  # Convert to string
                "Extracted_Description": str(match[2].strip()),  # Convert to string and strip any extra whitespace
                "Units": float(match[3]),  # Convert to float
                "Charges": float(match[4])  # Convert to float
            }
            billing_records.append(record)  # Append each record to the list

    # Create a DataFrame from the list of records
    df_billing_records = pd.DataFrame(billing_records)

    return df_billing_records  # Return the DataFrame

# %%
df_extracted = extract_billing_info_pdf(my_path)

# %%
df_extracted.head(50)
# Out:
#                                       Hospital       Date    CPT  \
# 0   The Houston Spine & Rehabilitation Centers 2024-01-24  97163
# 1   The Houston Spine & Rehabilitation Centers 2024-01-24  97014
# 2   The Houston Spine & Rehabilitation Centers 2024-01-30  97113
# 3   The Houston Spine & Rehabilitation Centers 2024-02-02  97140
# 4   The Houston Spine & Rehabilitation Centers 2024-02-02  97035
# 5   The Houston Spine & Rehabilitation Centers 2024-02-02  97014
# 6   The Houston Spine & Rehabilitation Centers 2024-02-06  97113
# 7   The Houston Spine & Rehabilitation Centers 2024-02-08  97113
# 8   The Houston Spine & Rehabilitation Centers 2024-02-08  97140
# 9   The Houston Spine & Rehabilitation Centers 2024-02-13  97113
# 10  The Houston Spine & Rehabilitation Centers 2024-02-13  97140
# 11  The Houston Spine & Rehabilitation Centers 2024-02-15  97113
# 12  The Houston Spine & Rehabilitation Centers 2024-02-20  97113
# 13  The Houston Spine & Rehabilitation Centers 2024-02-27  97113
# 14  The Houston Spine & Rehabilitation Centers 2024-02-29  97113
# 15  The Houston Spine & Rehabilitation Centers 2024-03-05  97113
# 16  The Houston Spine & Rehabilitation Centers 2024-03-07  97113
# 17  The Houston Spine & Rehabilitation Centers 2024-03-12  97164
# 18  The Houston Spine & Rehabilitation Centers 2024-03-12  97110
# 19  The Houston Spine & Rehabilitation Centers 2024-03-12  97014
# 20  The Houston Spine & Rehabilitation Centers 2024-03-14  97113
# 21  The Houston Spine & Rehabilitation Centers 2024-03-19  97110
# 22  The Houston Spine & Rehabilitation Centers 2024-03-19  97112
# 23  The Houston Spine & Rehabilitation Centers 2024-03-21  97113
# 24  The Houston Spine & Rehabilitation Centers 2024-03-26  97110
# 25  The Houston Spine & Rehabilitation Centers 2024-03-26  97112
# 26  The Houston Spine & Rehabilitation Centers 2024-03-29  97140
# 27  The Houston Spine & Rehabilitation Centers 2024-03-29  97035
# 28  The Houston Spine & Rehabilitation Centers 2024-03-29  97014
# 29  The Houston Spine & Rehabilitation Centers 2024-04-02  97110
# 25                       NEUROMUSCULAR RE-ED    2.0    200.0
# 26                            MANUAL THERAPY    1.0    100.0
# 27                                ULTRASOUND    1.0     38.0
# 28  APPL MODALITY 1+ AREAS ELEC STIMJ UNATTN    1.0     50.0
# 29                     THERAPEUTIC PROCEDURE    2.0    200.0
# 30                       NEUROMUSCULAR RE-ED    2.0    200.0
# 31                           AQUATIC THERAPY    4.0    500.0
# 32                     THERAPEUTIC PROCEDURE    1.0    100.0
# 33                       NEUROMUSCULAR RE-ED    3.0    300.0
# 34                           AQUATIC THERAPY    4.0    500.0
# 35                     THERAPEUTIC PROCEDURE    1.0    100.0
# 36                       NEUROMUSCULAR RE-ED    3.0    300.0
# 37                           AQUATIC THERAPY    4.0    500.0
# 38                     THERAPEUTIC PROCEDURE    1.0    100.0
# 39                       NEUROMUSCULAR RE-ED    3.0    300.0
# 40           Physical Therapy Re-Evaluaution    1.0     60.0
# 41                     THERAPEUTIC PROCEDURE    2.0    200.0
# 42                       NEUROMUSCULAR RE-ED    1.0    100.0
# 43  APPL MODALITY 1+ AREAS ELEC STIMJ UNATTN    1.0     50.0
# 44                  Decompression Traction-P    1.0    200.0
# 45                  Decompression Traction-P    1.0    200.0
# 46                     THERAPEUTIC PROCEDURE    1.0    100.0
# 47                       NEUROMUSCULAR RE-ED    2.0    200.0
# 48                     THERAPEUTIC PROCEDURE    1.0    100.0
# 49                       NEUROMUSCULAR RE-ED    2.0    200.0

# %%
# Matching columns CPT with Procedure Code


final_data = pd.merge(df_extracted,df_cpt,left_on='CPT', right_on='Procedure Code', how='left')
final_data.drop(columns=['Procedure Code'], inplace=True)
final_data.rename(columns={'Description': 'Provided_Description'}, inplace=True)
final_data.head()
# Out:
#                                      Hospital       Date    CPT  \
# 0  The Houston Spine & Rehabilitation Centers 2024-01-24  97163
# 1  The Houston Spine & Rehabilitation Centers 2024-01-24  97014
# 2  The Houston Spine & Rehabilitation Centers 2024-01-30  97113
# 3  The Houston Spine & Rehabilitation Centers 2024-02-02  97140
# 4  The Houston Spine & Rehabilitation Centers 2024-02-02  97035
#
#                       Extracted_Description  Units  Charges  \
# 0                Complex Initial Evaluation    1.0    110.0
# 1  APPL MODALITY 1+ AREAS ELEC STIMJ UNATTN    1.0     50.0
# 2                           AQUATIC THERAPY    4.0    500.0
# 3                            MANUAL THERAPY    1.0    100.0
# 4                                ULTRASOUND    1.0     38.0
#
#   Provided_Description
# 0     Pt eval high com
# 1            Elec stim
# 2     Aquatic therapy/
# 3             Man ther
# 4           US therapy

# %%
# Biling Charges Matching

final_data['Charges'].sum()
# Out:
# 21131.0

# %% [markdown]
# ### Convert to CSV

# %%
# final_data.to_csv('R000345 - R000349.csv')
